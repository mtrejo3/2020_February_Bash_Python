# %% [markdown]
# # Importing Packages

# %%
import pandas as pd #pd is the alias that we're giving pandas so that we don't have to type out pandas. pandas is for data analysis
import matplotlib.pyplot as plt #used to plot data
import glob #used to create a list of matching pathnames

# %%
countries = glob.glob('../shell-lessons/data/gapminder_data/gapminder_by_country/*.cc.txt') #create a list of matching pathnames

# %%
pwd
# Out:
# 'C:\\Users\\mtrej\\Desktop\\SDC_02-15-2020\\2020_February_Bash_Python\\python_day2'

# %%
ls ..\shell-lessons\data\gapminder_data\gapminder_by_country\
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is DC40-124B
#
#  Directory of C:\Users\mtrej\Desktop\SDC_02-15-2020\2020_February_Bash_Python\shell-lessons\data\gapminder_data\gapminder_by_country
#
# 15-Feb-20  10:52 AM    <DIR>          .
# 15-Feb-20  10:52 AM    <DIR>          ..
# 15-Feb-20  10:52 AM               604 Afghanistan.cc.txt
# 15-Feb-20  10:52 AM               563 Albania.cc.txt
# 15-Feb-20  10:52 AM               586 Algeria.cc.txt
# 15-Feb-20  10:52 AM               562 Angola.cc.txt
# 15-Feb-20  10:52 AM               633 Argentina.cc.txt
# 15-Feb-20  10:52 AM               610 Australia.cc.txt
# 15-Feb-20  10:52 AM               559 Austria.cc.txt
# 15-Feb-20  10:52 AM               536 Bahrain.cc.txt
# 15-Feb-20  10:52 AM               604 Bangladesh.cc.txt
# 15-Feb-20  10:52 AM               565 Belgium.cc.txt
# 15-Feb-20  10:52 AM               548 Benin.cc.txt
# 15-Feb-20  10:52 AM               596 Bolivia.cc.txt
# ...

# %%
countries
# Out:
# ['../shell-lessons/data/gapminder_data/gapminder_by_country\\Afghanistan.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Albania.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Algeria.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Angola.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Argentina.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Australia.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Austria.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bahrain.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bangladesh.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Belgium.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Benin.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bolivia.cc.txt',
# ...

# %%
countries [1]
# Out:
# '../shell-lessons/data/gapminder_data/gapminder_by_country\\Albania.cc.txt'

# %% [markdown]
# 1. For loop to import each file into pandas
# 2. Concatenate all files into a dataframe
# 3. Save the final datafram to file

# %%
df = pd.DataFrame()

for country in countries:
    c = pd.read_csv(country, sep='\t', header=None) #we have to tell pandas that the separator is a tab, not a comma
    df = df.append(c, ignore_index=True)

# %%
df
# Out:
#                 0     1            2       3       4        5
# 0     Afghanistan  1997  2.22274e+07    Asia  41.763  635.341
# 1     Afghanistan  2002  2.52684e+07    Asia  42.129  726.734
# 2     Afghanistan  2007  3.18899e+07    Asia  43.828   974.58
# 3     Afghanistan  1952  8.42533e+06    Asia  28.801  779.445
# 4     Afghanistan  1957  9.24093e+06    Asia  30.332  820.853
# ...           ...   ...          ...     ...     ...      ...
# 1700     Zimbabwe  1987      9216418  Africa  62.351  706.157
# 1701     Zimbabwe  1992     10704340  Africa  60.377  693.421
# 1702     Zimbabwe  1997     11404948  Africa  46.809   792.45
# 1703     Zimbabwe  2002     11926563  Africa  39.989  672.039
# 1704     Zimbabwe  2007     12311143  Africa  43.487  469.709
#
# [1705 rows x 6 columns]

# %%
sorted(countries)
# Out:
# ['../shell-lessons/data/gapminder_data/gapminder_by_country\\Afghanistan.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Albania.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Algeria.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Angola.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Argentina.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Australia.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Austria.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bahrain.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bangladesh.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Belgium.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Benin.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bolivia.cc.txt',
# ...

# %%
for item in countries:
    if item.endswith("country.cc.txt"):
        print('found it')
        countries.remove(item)

# %%
for item in countries:
    if item.endswith("country.cc.txt"):
        print('found it')

# %%
df = pd.DataFrame()

for country in countries:
    c = pd.read_csv(country, sep='\t', header=None) #we have to tell pandas that the separator is a tab, not a comma
    df = df.append(c, ignore_index=True)

# %%
df
# Out:
#                 0     1           2       3       4           5
# 0     Afghanistan  1997  22227415.0    Asia  41.763  635.341351
# 1     Afghanistan  2002  25268405.0    Asia  42.129  726.734055
# 2     Afghanistan  2007  31889923.0    Asia  43.828  974.580338
# 3     Afghanistan  1952   8425333.0    Asia  28.801  779.445314
# 4     Afghanistan  1957   9240934.0    Asia  30.332  820.853030
# ...           ...   ...         ...     ...     ...         ...
# 1699     Zimbabwe  1987   9216418.0  Africa  62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0  Africa  60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0  Africa  46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0  Africa  39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0  Africa  43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.shape[0] # number of rows
# Out:
# 1704

# %%
df.columns #a list of our current column names
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
df.columns = ['Country', 'Year', 'Population','Continent','LifeExp','gdpPercap'] #replace current column names with this list

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Population', 'Continent', 'LifeExp', 'gdpPercap'], dtype='object')

# %%
df
# Out:
#           Country  Year  Population Continent  LifeExp   gdpPercap
# 0     Afghanistan  1997  22227415.0      Asia   41.763  635.341351
# 1     Afghanistan  2002  25268405.0      Asia   42.129  726.734055
# 2     Afghanistan  2007  31889923.0      Asia   43.828  974.580338
# 3     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 4     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df
# Out:
#           Country  Year  Population Continent  LifeExp   gdpPercap
# 0     Afghanistan  1997  22227415.0      Asia   41.763  635.341351
# 1     Afghanistan  2002  25268405.0      Asia   42.129  726.734055
# 2     Afghanistan  2007  31889923.0      Asia   43.828  974.580338
# 3     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 4     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df = df[['Continent','Country', 'Year', 'Population',  
         'LifeExp', 'gdpPercap']] # to rearrange our dataframe

# %%
df
# Out:
#      Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 1         Asia  Afghanistan  2002  25268405.0   42.129  726.734055
# 2         Asia  Afghanistan  2007  31889923.0   43.828  974.580338
# 3         Asia  Afghanistan  1952   8425333.0   28.801  779.445314
# 4         Asia  Afghanistan  1957   9240934.0   30.332  820.853030
# ...        ...          ...   ...         ...      ...         ...
# 1699    Africa     Zimbabwe  1987   9216418.0   62.351  706.157306
# 1700    Africa     Zimbabwe  1992  10704340.0   60.377  693.420786
# 1701    Africa     Zimbabwe  1997  11404948.0   46.809  792.449960
# 1702    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by=['Country']) # when we sort the index on the far left can get switched unless we reset as below
# Out:
#      Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 11        Asia  Afghanistan  1992  16317921.0   41.674  649.341395
# 10        Asia  Afghanistan  1987  13867957.0   40.822  852.395945
# 9         Asia  Afghanistan  1982  12881816.0   39.854  978.011439
# 7         Asia  Afghanistan  1972  13079460.0   36.088  739.981106
# ...        ...          ...   ...         ...      ...         ...
# 1693    Africa     Zimbabwe  1957   3646340.0   50.469  518.764268
# 1692    Africa     Zimbabwe  1952   3080907.0   48.451  406.884115
# 1702    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1696    Africa     Zimbabwe  1972   5861135.0   55.635  799.362176
# 1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by=['Country']).reset_index()
# Out:
#       index Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         0      Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 1        11      Asia  Afghanistan  1992  16317921.0   41.674  649.341395
# 2        10      Asia  Afghanistan  1987  13867957.0   40.822  852.395945
# 3         9      Asia  Afghanistan  1982  12881816.0   39.854  978.011439
# 4         7      Asia  Afghanistan  1972  13079460.0   36.088  739.981106
# ...     ...       ...          ...   ...         ...      ...         ...
# 1699   1693    Africa     Zimbabwe  1957   3646340.0   50.469  518.764268
# 1700   1692    Africa     Zimbabwe  1952   3080907.0   48.451  406.884115
# 1701   1702    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1702   1696    Africa     Zimbabwe  1972   5861135.0   55.635  799.362176
# 1703   1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 7 columns]

# %%
df.sort_values(by=['Country']).reset_index(drop=True) #make sure to include drop=True or index will be added as a var
# Out:
#      Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 1         Asia  Afghanistan  1992  16317921.0   41.674  649.341395
# 2         Asia  Afghanistan  1987  13867957.0   40.822  852.395945
# 3         Asia  Afghanistan  1982  12881816.0   39.854  978.011439
# 4         Asia  Afghanistan  1972  13079460.0   36.088  739.981106
# ...        ...          ...   ...         ...      ...         ...
# 1699    Africa     Zimbabwe  1957   3646340.0   50.469  518.764268
# 1700    Africa     Zimbabwe  1952   3080907.0   48.451  406.884115
# 1701    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1702    Africa     Zimbabwe  1972   5861135.0   55.635  799.362176
# 1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by=['LifeExp','Continent','Country']).reset_index(drop=True) #make sure to include drop=True or index will be added as a var
# Out:
#      Continent           Country  Year   Population  LifeExp     gdpPercap
# 0       Africa            Rwanda  1992    7290203.0   23.599    737.068595
# 1         Asia       Afghanistan  1952    8425333.0   28.801    779.445314
# 2       Africa            Gambia  1952     284320.0   30.000    485.230659
# 3       Africa            Angola  1952    4232095.0   30.015   3520.610273
# 4       Africa      Sierra Leone  1952    2143249.0   30.331    879.787736
# ...        ...               ...   ...          ...      ...           ...
# 1699    Europe       Switzerland  2007    7554661.0   81.701  37506.419070
# 1700    Europe           Iceland  2007     301931.0   81.757  36180.789190
# 1701      Asia             Japan  2002  127065841.0   82.000  28604.591900
# 1702      Asia  Hong Kong, China  2007    6980412.0   82.208  39724.978670
# 1703      Asia             Japan  2007  127467972.0   82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by=['Country']).reset_index(drop=True) #make sure to include drop=True or index will be added as a var
# Out:
#      Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 1         Asia  Afghanistan  1992  16317921.0   41.674  649.341395
# 2         Asia  Afghanistan  1987  13867957.0   40.822  852.395945
# 3         Asia  Afghanistan  1982  12881816.0   39.854  978.011439
# 4         Asia  Afghanistan  1972  13079460.0   36.088  739.981106
# ...        ...          ...   ...         ...      ...         ...
# 1699    Africa     Zimbabwe  1957   3646340.0   50.469  518.764268
# 1700    Africa     Zimbabwe  1952   3080907.0   48.451  406.884115
# 1701    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1702    Africa     Zimbabwe  1972   5861135.0   55.635  799.362176
# 1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df=df.sort_values(by=['Country']).reset_index(drop=True) #if we actually want to make changes we have to include df=

# %%
df.to_csv('gapminder_all.csv', index=False) #save our data to a csv file. we don't want the index because it's not meaningful

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is DC40-124B
#
#  Directory of C:\Users\mtrej\Desktop\SDC_02-15-2020\2020_February_Bash_Python\python_day2
#
# 16-Feb-20  02:15 PM    <DIR>          .
# 16-Feb-20  02:15 PM    <DIR>          ..
# 16-Feb-20  01:09 PM    <DIR>          .ipynb_checkpoints
# 16-Feb-20  02:15 PM            94,082 gapminder_all.csv
# 16-Feb-20  01:06 PM            15,769 review_of_python.ipynb
# 16-Feb-20  02:15 PM            97,990 Untitled.ipynb
#                3 File(s)        207,841 bytes
#                3 Dir(s)  280,325,505,024 bytes free

# %%
df.describe() #pandas calculates summary stats. This command for that
# Out:
#              Year    Population      LifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165877
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846989
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df.describe().to_csv('gapminder_summ_stats.csv') #here we want the index because it's meaningful

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is DC40-124B
#
#  Directory of C:\Users\mtrej\Desktop\SDC_02-15-2020\2020_February_Bash_Python\python_day2
#
# 16-Feb-20  02:20 PM    <DIR>          .
# 16-Feb-20  02:20 PM    <DIR>          ..
# 16-Feb-20  01:09 PM    <DIR>          .ipynb_checkpoints
# 16-Feb-20  02:20 PM            94,082 gapminder_all.csv
# 16-Feb-20  02:20 PM               444 gapminder_summ_stats.csv
# 16-Feb-20  01:06 PM            15,769 review_of_python.ipynb
# 16-Feb-20  02:19 PM           102,785 Untitled.ipynb
#                4 File(s)        213,080 bytes
#                3 Dir(s)  280,328,110,080 bytes free

# %% [markdown]
# # Slicing
#
# `loc[]` to select values by the name
# `loc[a:b, i:j]` where
# a and be are the row/countries
# i and j are the columns/years

# %%
df
# Out:
#      Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 1         Asia  Afghanistan  1992  16317921.0   41.674  649.341395
# 2         Asia  Afghanistan  1987  13867957.0   40.822  852.395945
# 3         Asia  Afghanistan  1982  12881816.0   39.854  978.011439
# 4         Asia  Afghanistan  1972  13079460.0   36.088  739.981106
# ...        ...          ...   ...         ...      ...         ...
# 1699    Africa     Zimbabwe  1957   3646340.0   50.469  518.764268
# 1700    Africa     Zimbabwe  1952   3080907.0   48.451  406.884115
# 1701    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1702    Africa     Zimbabwe  1972   5861135.0   55.635  799.362176
# 1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df = df.set_index('Country') # replaces index shows above with Country names
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-50b8fb1eef2f> in <module>
# ----> 1 df = df.set_index('Country') # replaces index shows above with Country names
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"

# %%
df
# Out:
#             Continent  Year  Population  LifeExp   gdpPercap
# Country
# Afghanistan      Asia  1997  22227415.0   41.763  635.341351
# Afghanistan      Asia  1992  16317921.0   41.674  649.341395
# Afghanistan      Asia  1987  13867957.0   40.822  852.395945
# Afghanistan      Asia  1982  12881816.0   39.854  978.011439
# Afghanistan      Asia  1972  13079460.0   36.088  739.981106
# ...               ...   ...         ...      ...         ...
# Zimbabwe       Africa  1957   3646340.0   50.469  518.764268
# Zimbabwe       Africa  1952   3080907.0   48.451  406.884115
# Zimbabwe       Africa  2002  11926563.0   39.989  672.038623
# Zimbabwe       Africa  1972   5861135.0   55.635  799.362176
# Zimbabwe       Africa  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.loc['Brazil':'Ecuador', 'Year':'LifeExp']
# Out:
#          Year   Population  LifeExp
# Country
# Brazil   2002  179914212.0   71.006
# Brazil   1997  168546719.0   69.388
# Brazil   1992  155975974.0   67.057
# Brazil   1987  142938076.0   65.205
# Brazil   1982  128962939.0   63.336
# ...       ...          ...      ...
# Ecuador  1967    5432424.0   56.678
# Ecuador  1962    4681707.0   54.640
# Ecuador  1957    4058385.0   51.356
# Ecuador  1952    3548753.0   48.357
# Ecuador  1977    7278866.0   61.310
#
# [288 rows x 3 columns]

# %%
df.loc['Brazil':'Ecuador']
# Out:
#         Continent  Year   Population  LifeExp    gdpPercap
# Country
# Brazil   Americas  2002  179914212.0   71.006  8131.212843
# Brazil   Americas  1997  168546719.0   69.388  7957.980824
# Brazil   Americas  1992  155975974.0   67.057  6950.283021
# Brazil   Americas  1987  142938076.0   65.205  7807.095818
# Brazil   Americas  1982  128962939.0   63.336  7030.835878
# ...           ...   ...          ...      ...          ...
# Ecuador  Americas  1967    5432424.0   56.678  4579.074215
# Ecuador  Americas  1962    4681707.0   54.640  4086.114078
# Ecuador  Americas  1957    4058385.0   51.356  3780.546651
# Ecuador  Americas  1952    3548753.0   48.357  3522.110717
# Ecuador  Americas  1977    7278866.0   61.310  6679.623260
#
# [288 rows x 5 columns]

# %%
df.loc['Brazil']
# Out:
#         Continent  Year   Population  LifeExp    gdpPercap
# Country
# Brazil   Americas  2002  179914212.0   71.006  8131.212843
# Brazil   Americas  1997  168546719.0   69.388  7957.980824
# Brazil   Americas  1992  155975974.0   67.057  6950.283021
# Brazil   Americas  1987  142938076.0   65.205  7807.095818
# Brazil   Americas  1982  128962939.0   63.336  7030.835878
# Brazil   Americas  2007  190010647.0   72.390  9065.800825
# Brazil   Americas  1972  100840058.0   59.504  4985.711467
# Brazil   Americas  1967   88049823.0   57.632  3429.864357
# Brazil   Americas  1962   76039390.0   55.665  3336.585802
# Brazil   Americas  1957   65551171.0   53.285  2487.365989
# Brazil   Americas  1952   56602560.0   50.917  2108.944355
# Brazil   Americas  1977  114313951.0   61.489  6660.118654

# %%
df.loc[['Brazil','Ecuador'],'Year':'LifeExp'] #Brazil and Ecuador within double brackets because it is a list of what we want
# Out:
#          Year   Population  LifeExp
# Country
# Brazil   2002  179914212.0   71.006
# Brazil   1997  168546719.0   69.388
# Brazil   1992  155975974.0   67.057
# Brazil   1987  142938076.0   65.205
# Brazil   1982  128962939.0   63.336
# Brazil   2007  190010647.0   72.390
# Brazil   1972  100840058.0   59.504
# Brazil   1967   88049823.0   57.632
# Brazil   1962   76039390.0   55.665
# Brazil   1957   65551171.0   53.285
# Brazil   1952   56602560.0   50.917
# Brazil   1977  114313951.0   61.489
# Ecuador  2007   13755680.0   74.994
# Ecuador  2002   12921234.0   74.173
# Ecuador  1997   11911819.0   72.312
# Ecuador  1992   10748394.0   69.613
# Ecuador  1987    9545158.0   67.231
# Ecuador  1982    8365850.0   64.342
# Ecuador  1972    6298651.0   58.796
# Ecuador  1967    5432424.0   56.678
# Ecuador  1962    4681707.0   54.640
# Ecuador  1957    4058385.0   51.356
# Ecuador  1952    3548753.0   48.357
# Ecuador  1977    7278866.0   61.310

# %%
df.loc[['Brazil','Ecuador'],['Year','LifeExp']]
# Out:
#          Year  LifeExp
# Country
# Brazil   2002   71.006
# Brazil   1997   69.388
# Brazil   1992   67.057
# Brazil   1987   65.205
# Brazil   1982   63.336
# Brazil   2007   72.390
# Brazil   1972   59.504
# Brazil   1967   57.632
# Brazil   1962   55.665
# Brazil   1957   53.285
# Brazil   1952   50.917
# Brazil   1977   61.489
# Ecuador  2007   74.994
# Ecuador  2002   74.173
# Ecuador  1997   72.312
# Ecuador  1992   69.613
# Ecuador  1987   67.231
# Ecuador  1982   64.342
# Ecuador  1972   58.796
# Ecuador  1967   56.678
# Ecuador  1962   54.640
# Ecuador  1957   51.356
# Ecuador  1952   48.357
# Ecuador  1977   61.310

# %%
df.iloc[9:16,1:3] # iloc can be used for particular numbers within the set. here rows 9-16 and rows 1-3
# Out:
#              Year  Population
# Country
# Afghanistan  2007  31889923.0
# Afghanistan  2002  25268405.0
# Afghanistan  1962  10267083.0
# Albania      1987   3075321.0
# Albania      2007   3600523.0
# Albania      2002   3508512.0
# Albania      1997   3428038.0

# %%
df.iloc[9:16,0:2]
# Out:
#             Continent  Year
# Country
# Afghanistan      Asia  2007
# Afghanistan      Asia  2002
# Afghanistan      Asia  1962
# Albania        Europe  1987
# Albania        Europe  2007
# Albania        Europe  2002
# Albania        Europe  1997

# %% [markdown]
# # Exercise
#
# Select two countries of your interest.
#
# slice the df to select only these countries
#
# Then obtain summary statistics by country and save to a file

# %%
elsal = df.loc['El Salvador']

# %%
zamb = df.loc['Zambia']

# %%
elsal.describe()
# Out:
#               Year    Population    LifeExp    gdpPercap
# count    12.000000  1.200000e+01  12.000000    12.000000
# mean   1979.500000  4.343441e+06  59.633333  4431.846597
# std      18.027756  1.575966e+06   8.799018   804.700697
# min    1952.000000  2.042865e+06  45.262000  3048.302900
# 25%    1965.750000  3.111617e+06  54.968000  4017.959038
# 50%    1979.500000  4.378730e+06  57.451500  4401.413546
# 75%    1993.250000  5.401846e+06  67.482250  5142.898154
# max    2007.000000  6.939688e+06  71.878000  5728.353514

# %%
zamb.describe()
# Out:
#               Year    Population    LifeExp    gdpPercap
# count    12.000000  1.200000e+01  12.000000    12.000000
# mean   1979.500000  6.353805e+06  45.996333  1358.199409
# std      18.027756  3.096949e+06   4.453246   247.494984
# min    1952.000000  2.672000e+06  39.193000  1071.353818
# 25%    1965.750000  3.780250e+06  42.297500  1195.010683
# 50%    1979.500000  5.658478e+06  46.061500  1291.584180
# 75%    1993.250000  8.640320e+06  50.285500  1486.716399
# max    2007.000000  1.174604e+07  51.821000  1777.077318

# %%
elsalzamb=df.loc[['El Salvador','Zambia']].describe().to_csv('elsalzamb_summ_stats.csv') #create csv with summary stats for zamb and elsal

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is DC40-124B
#
#  Directory of C:\Users\mtrej\Desktop\SDC_02-15-2020\2020_February_Bash_Python\python_day2
#
# 16-Feb-20  02:42 PM    <DIR>          .
# 16-Feb-20  02:42 PM    <DIR>          ..
# 16-Feb-20  01:09 PM    <DIR>          .ipynb_checkpoints
# 16-Feb-20  02:42 PM               465 elsalzamb_summ_stats.csv
# 16-Feb-20  02:20 PM            94,082 gapminder_all.csv
# 16-Feb-20  02:20 PM               444 gapminder_summ_stats.csv
# 16-Feb-20  01:06 PM            15,769 review_of_python.ipynb
# 16-Feb-20  02:41 PM           153,680 Untitled.ipynb
#                5 File(s)        264,440 bytes
#                3 Dir(s)  280,325,595,136 bytes free

# %%
# %matplotlib inline

# %%
# this is to make sure that we can see a plot
time =[0,1,2,3,4]
position = [0,100,200,300,400]
plt.plot (time,position)

# %%
df
# Out:
#             Continent  Year  Population  LifeExp   gdpPercap
# Country
# Afghanistan      Asia  1997  22227415.0   41.763  635.341351
# Afghanistan      Asia  1992  16317921.0   41.674  649.341395
# Afghanistan      Asia  1987  13867957.0   40.822  852.395945
# Afghanistan      Asia  1982  12881816.0   39.854  978.011439
# Afghanistan      Asia  1972  13079460.0   36.088  739.981106
# ...               ...   ...         ...      ...         ...
# Zimbabwe       Africa  1957   3646340.0   50.469  518.764268
# Zimbabwe       Africa  1952   3080907.0   48.451  406.884115
# Zimbabwe       Africa  2002  11926563.0   39.989  672.038623
# Zimbabwe       Africa  1972   5861135.0   55.635  799.362176
# Zimbabwe       Africa  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
# line plots need countries in columns, and currently they're in rows
gdp_oceania = df.loc[['Australia', 'New Zealand'], ['Year', 'gdpPercap']]

# %%
gdp_oceania
# Out:
#              Year    gdpPercap
# Country
# Australia    2007  34435.36744
# Australia    2002  30687.75473
# Australia    1997  26997.93657
# Australia    1987  21888.88903
# Australia    1977  18334.19751
# Australia    1992  23424.76683
# Australia    1967  14526.12465
# Australia    1962  12217.22686
# Australia    1957  10949.64959
# Australia    1952  10039.59564
# Australia    1972  16788.62948
# Australia    1982  19477.00928
# New Zealand  2007  25185.00911
# New Zealand  2002  23189.80135
# New Zealand  1997  21050.41377
# New Zealand  1992  18363.32494
# New Zealand  1987  19007.19129
# New Zealand  1982  17632.41040
# New Zealand  1977  16233.71770
# New Zealand  1972  16046.03728
# New Zealand  1967  14463.91893
# New Zealand  1962  13175.67800
# New Zealand  1957  12247.39532
# New Zealand  1952  10556.57566

# %%
gdp_oceania = pd.pivot_table(gdp_oceania, values='gdpPercap', index='Year', columns='Country') #countries are now columns

# %%
gdp_oceania
# Out:
# Country    Australia  New Zealand
# Year
# 1952     10039.59564  10556.57566
# 1957     10949.64959  12247.39532
# 1962     12217.22686  13175.67800
# 1967     14526.12465  14463.91893
# 1972     16788.62948  16046.03728
# 1977     18334.19751  16233.71770
# 1982     19477.00928  17632.41040
# 1987     21888.88903  19007.19129
# 1992     23424.76683  18363.32494
# 1997     26997.93657  21050.41377
# 2002     30687.75473  23189.80135
# 2007     34435.36744  25185.00911

# %%
plt.plot(gdp_oceania);

# %%
plt.plot(gdp_oceania)
plt.xlabel('Year') # taking them as integers
plt.ylabel('GDP per capita, $1,000')
plt.title ('GAPMINDER');

# %%
plt.plot(gdp_oceania.loc[:,'Australia'],'k:',label='Australia') #k means black, : means dotted
plt.plot(gdp_oceania.loc[:,"New Zealand"],'r-', label="New Zealand")
plt.legend(loc="best"); #loc=1 means location of legend 1 is upper right, 2 is upper left and "best" will look for best location

# %%
gdp_oceania.plot(kind="barh"); #plotting through pandas here intead of matplotlibs

# %%
gdp_oceania.plot(kind='bar');

# %%
gdp_oceania.plot(); #line is by default

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.style.use('ggplot')

# %%
gdp_oceania.plot();

# %%
gdp_oceania.plot(kind='bar'); 
plt.savefig('oceania_bar.png', dpi=300) #save plot to png @ 300 dpi

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is DC40-124B
#
#  Directory of C:\Users\mtrej\Desktop\SDC_02-15-2020\2020_February_Bash_Python\python_day2
#
# 16-Feb-20  03:39 PM    <DIR>          .
# 16-Feb-20  03:39 PM    <DIR>          ..
# 16-Feb-20  01:09 PM    <DIR>          .ipynb_checkpoints
# 16-Feb-20  02:42 PM               465 elsalzamb_summ_stats.csv
# 16-Feb-20  02:20 PM            94,082 gapminder_all.csv
# 16-Feb-20  02:20 PM               444 gapminder_summ_stats.csv
# 16-Feb-20  03:38 PM            66,806 oceania_bar.png
# 16-Feb-20  01:06 PM            15,769 review_of_python.ipynb
# 16-Feb-20  03:39 PM           338,664 Untitled.ipynb
#                6 File(s)        516,230 bytes
#                3 Dir(s)  280,145,395,712 bytes free

# %% [markdown]
# ## The following will give manual for matplotlib function

# %%
# ?plt.savefig

# %%
gdp_oceania.plot(kind='bar')
plt.savefig('oceania_bar.svg',dpi=300, format='svg')

# %%
df
# Out:
#             Continent  Year  Population  LifeExp   gdpPercap
# Country
# Afghanistan      Asia  1997  22227415.0   41.763  635.341351
# Afghanistan      Asia  1992  16317921.0   41.674  649.341395
# Afghanistan      Asia  1987  13867957.0   40.822  852.395945
# Afghanistan      Asia  1982  12881816.0   39.854  978.011439
# Afghanistan      Asia  1972  13079460.0   36.088  739.981106
# ...               ...   ...         ...      ...         ...
# Zimbabwe       Africa  1957   3646340.0   50.469  518.764268
# Zimbabwe       Africa  1952   3080907.0   48.451  406.884115
# Zimbabwe       Africa  2002  11926563.0   39.989  672.038623
# Zimbabwe       Africa  1972   5861135.0   55.635  799.362176
# Zimbabwe       Africa  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
subset_yr = df.reset_index().loc[:,['Year','gdpPercap','Country']]

# %%
subset_yr
# Out:
#       Year   gdpPercap      Country
# 0     1997  635.341351  Afghanistan
# 1     1992  649.341395  Afghanistan
# 2     1987  852.395945  Afghanistan
# 3     1982  978.011439  Afghanistan
# 4     1972  739.981106  Afghanistan
# ...    ...         ...          ...
# 1699  1957  518.764268     Zimbabwe
# 1700  1952  406.884115     Zimbabwe
# 1701  2002  672.038623     Zimbabwe
# 1702  1972  799.362176     Zimbabwe
# 1703  2007  469.709298     Zimbabwe
#
# [1704 rows x 3 columns]

# %%
subset_yr = subset_yr[ subset_yr['Year'].isin([1952, 2007]) ] #filter data to only include 1957 and 2007

# %%
subset_yr
# Out:
# Country  Afghanistan      Albania      Algeria       Angola     Argentina  \
# Year
# 1952      779.445314  1601.056136  2449.008185  3520.610273   5911.315053
# 2007      974.580338  5937.029526  6223.367465  4797.231267  12779.379640
#
# Country    Australia       Austria       Bahrain   Bangladesh       Belgium  \
# Year
# 1952     10039.59564   6137.076492   9867.084765   684.244172   8343.105127
# 2007     34435.36744  36126.492700  29796.048340  1391.253792  33692.605080
#
# Country  ...       Uganda  United Kingdom  United States       Uruguay  \
# Year     ...
# 1952     ...   734.753484     9979.508487    13990.48208   5716.766744
# 2007     ...  1056.380121    33203.261280    42951.65309  10611.462990
#
# Country     Venezuela      Vietnam  West Bank and Gaza  Yemen, Rep.  \
# Year
# 1952      7689.799761   605.066492         1515.592329   781.717576
# 2007     11415.805690  2441.576404         3025.349798  2280.769906
#
# Country       Zambia    Zimbabwe
# Year
# ...

# %%
subset_yr = subset_yr.pivot_table(values="gdpPercap", index='Year', columns='Country')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-208-7deb19953c3b> in <module>
# ----> 1 subset_yr = subset_yr.pivot_table(values="gdpPercap", index='Year', columns='Country')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6072             dropna=dropna,
#    6073             margins_name=margins_name,
# -> 6074             observed=observed,
#    6075         )
#    6076
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      70         for i in values:
#      71             if i not in data:
# ---> 72                 raise KeyError(i)
#      73
#      74         to_filter = []
#
# KeyError: 'gdpPercap'

# %%
subset_yr # now we have
# Out:
# Country  Afghanistan      Albania      Algeria       Angola     Argentina  \
# Year
# 1952      779.445314  1601.056136  2449.008185  3520.610273   5911.315053
# 2007      974.580338  5937.029526  6223.367465  4797.231267  12779.379640
#
# Country    Australia       Austria       Bahrain   Bangladesh       Belgium  \
# Year
# 1952     10039.59564   6137.076492   9867.084765   684.244172   8343.105127
# 2007     34435.36744  36126.492700  29796.048340  1391.253792  33692.605080
#
# Country  ...       Uganda  United Kingdom  United States       Uruguay  \
# Year     ...
# 1952     ...   734.753484     9979.508487    13990.48208   5716.766744
# 2007     ...  1056.380121    33203.261280    42951.65309  10611.462990
#
# Country     Venezuela      Vietnam  West Bank and Gaza  Yemen, Rep.  \
# Year
# 1952      7689.799761   605.066492         1515.592329   781.717576
# 2007     11415.805690  2441.576404         3025.349798  2280.769906
#
# Country       Zambia    Zimbabwe
# Year
# ...

# %%
plt.hist(subset_yr, bins=100, stacked=True, 
         alpha=0.8, label=subset_yr.index.values); #using the semicolon will omit the arrays in the beginning
plt.legend() #alpha makes our bins a bit transparent
plt.xlim(0,60000); #controlling the x-axis labels - this cuts off graph before the outlier

# %%
plt.style.use('classic')

# %%
plt.hist(subset_yr, bins=100, stacked=True, 
         alpha=0.8, label=subset_yr.index.values); #using the semicolon will omit the arrays in the beginning
plt.legend() #alpha makes our bins a bit transparent
plt.xlim(0,60000); #controlling the x-axis labels - this cuts off graph before the outlier
